# %%
import os
from PIL import Image
import ipyplot

# %%
from decimer_image_classifier.decimer_image_classifier import DecimerImageClassifier
# Out:
# 2024-07-21 16:04:04.379006: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-21 16:04:04.446299: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-21 16:04:04.447324: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-21 16:04:05.640600: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
decimer_classifier = DecimerImageClassifier()
# Out:
# 2024-07-21 16:04:41.941829: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-21 16:04:42.011637: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# model_path: /home/pn02/Documents/github/honeyComb/models/classification/decimer_image_classifier/model

# %%
test_dir = "./example_data/test/chem"
images = os.listdir(test_dir)
images_loaded=[]
for img_path in images:
    img = Image.open(os.path.join(test_dir, img_path))
    score = decimer_classifier.get_classifier_score(img)
    is_chem = decimer_classifier.is_chemical_structure(img)
    images_loaded.append(img)
    print(f'{img_path} has a predicted score of {score}. Is it a chemical? {is_chem}')

ipyplot.plot_images(images_loaded, max_images=8, img_width=100)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# re_CHEMBL10010_2.png has a predicted score of 6.140013283584267e-05. Is it a chemical? True
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# re_CHEMBL100472_2.png has a predicted score of 2.208793925214704e-14. Is it a chemical? True
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 87ms/step
# re_CHEMBL100122_1.png has a predicted score of 8.063191227983962e-14. Is it a chemical? True
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# re_CHEMBL100304_1.png has a predicted score of 1.3034294852332096e-06. Is it a chemical? True
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 74ms/step
# re_CHEMBL10041_3.png has a predicted score of 7.050708017430907e-09. Is it a chemical? True
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 74ms/step
# re_CHEMBL100333_3.png has a predicted score of 2.3379104099711945e-13. Is it a chemical? True
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 75ms/step
# re_CHEMBL100234_0.png has a predicted score of 1.344882625403665e-11. Is it a chemical? True
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 76ms/step
# re_CHEMBL100154_1.png has a predicted score of 3.2892202416617833e-12. Is it a chemical? True
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 80ms/step
# re_CHEMBL100218_2.png has a predicted score of 8.246452735353061e-15. Is it a chemical? True
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 81ms/step
# re_CHEMBL100089_1.png has a predicted score of 2.880229832413761e-09. Is it a chemical? True
# /home/pn02/miniconda3/envs/decimer_cla/lib/python3.8/site-packages/ipyplot/_utils.py:95: FutureWarning: The input object of type 'PngImageFile' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'PngImageFile', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return np.asarray(seq, dtype=type(seq[0]))
#     <style>
#         #ipyplot-html-viewer-toggle-9fMwMyKx6Bj9xAYxsXkm4P {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9fMwMyKx6Bj9xAYxsXkm4P {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9fMwMyKx6Bj9xAYxsXkm4P {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9fMwMyKx6Bj9xAYxsXkm4P:checked ~ #ipyplot-html-viewer-textarea-9fMwMyKx6Bj9xAYxsXkm4P {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9fMwMyKx6Bj9xAYxsXkm4P:checked + #ipyplot-html-viewer-label-9fMwMyKx6Bj9xAYxsXkm4P:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9fMwMyKx6Bj9xAYxsXkm4P">
#         <label id="ipyplot-html-viewer-label-9fMwMyKx6Bj9xAYxsXkm4P" for="ipyplot-html-viewer-toggle-9fMwMyKx6Bj9xAYxsXkm4P">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9fMwMyKx6Bj9xAYxsXkm4P" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2AQr5x39T3prNYbaWd7tMW">
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-jGTboXyEBUZwoDaZwMMkm7" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-jGTboXyEBUZwoDaZwMMkm7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-8EyGgh4BtAspv5YF8sJf8S" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-8EyGgh4BtAspv5YF8sJf8S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-F8jJLdqZsHpzLi6vaEb85x" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-F8jJLdqZsHpzLi6vaEb85x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-Yb3gWxmf6Fn2yPv9XoTi5b" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-Yb3gWxmf6Fn2yPv9XoTi5b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-hMPY7vW2Pn2X9UEfNPFsn2" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-hMPY7vW2Pn2X9UEfNPFsn2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-An4hGuXmUrWwSQJWoUwVSF" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-An4hGuXmUrWwSQJWoUwVSF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-GqKfPx7orgA6zCAP7mB3mL" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-GqKfPx7orgA6zCAP7mB3mL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-2443JQFoDEgnfjWCj734m
#         <style>
#         #ipyplot-imgs-container-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2AQr5x39T3prNYbaWd7tMW">
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-jGTboXyEBUZwoDaZwMMkm7" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-jGTboXyEBUZwoDaZwMMkm7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-8EyGgh4BtAspv5YF8sJf8S" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-8EyGgh4BtAspv5YF8sJf8S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-F8jJLdqZsHpzLi6vaEb85x" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-F8jJLdqZsHpzLi6vaEb85x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-Yb3gWxmf6Fn2yPv9XoTi5b" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-Yb3gWxmf6Fn2yPv9XoTi5b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-hMPY7vW2Pn2X9UEfNPFsn2" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-hMPY7vW2Pn2X9UEfNPFsn2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-An4hGuXmUrWwSQJWoUwVSF" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-An4hGuXmUrWwSQJWoUwVSF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-GqKfPx7orgA6zCAP7mB3mL" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-GqKfPx7orgA6zCAP7mB3mL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2AQr5x39T3prNYbaWd7tMW">
#         <div id="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-2443JQFoDEgnfjWCj734mu" class="ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2AQr5x39T3prNYbaWd7tMW-2443JQFoDEgnfjWCj734mu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
test_dir = "./example_data/test/not_chem"
images = os.listdir(test_dir)
images_loaded=[]
for img_path in images:
    img = Image.open(os.path.join(test_dir, img_path))
    score = decimer_classifier.get_classifier_score(img)
    is_chem = decimer_classifier.is_chemical_structure(img)
    images_loaded.append(img)
    print(f'{img_path} has a predicted score of {score}. Is it a chemical? {is_chem}')

ipyplot.plot_images(images_loaded, max_images=8, img_width=100)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# re_000000000331.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 70ms/step
# re_000000000201.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# re_000000000491.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 75ms/step
# re_000000000545.jpg has a predicted score of 0.9999998807907104. Is it a chemical? False
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# re_000000000024.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 76ms/step
# re_000000000180.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 77ms/step
# re_000000000312.jpg has a predicted score of 0.9999977350234985. Is it a chemical? False
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 78ms/step
# re_000000000272.jpg has a predicted score of 0.9999993443489075. Is it a chemical? False
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 74ms/step
# re_000000000176.jpg has a predicted score of 1.0. Is it a chemical? False
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 163ms/step
# re_000000000205.jpg has a predicted score of 1.0. Is it a chemical? False
# /home/pn02/miniconda3/envs/decimer_cla/lib/python3.8/site-packages/ipyplot/_utils.py:95: FutureWarning: The input object of type 'JpegImageFile' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'JpegImageFile', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return np.asarray(seq, dtype=type(seq[0]))
#     <style>
#         #ipyplot-html-viewer-toggle-TDAV5EW4jM7WJWaxWThxvG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TDAV5EW4jM7WJWaxWThxvG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TDAV5EW4jM7WJWaxWThxvG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TDAV5EW4jM7WJWaxWThxvG:checked ~ #ipyplot-html-viewer-textarea-TDAV5EW4jM7WJWaxWThxvG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TDAV5EW4jM7WJWaxWThxvG:checked + #ipyplot-html-viewer-label-TDAV5EW4jM7WJWaxWThxvG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TDAV5EW4jM7WJWaxWThxvG">
#         <label id="ipyplot-html-viewer-label-TDAV5EW4jM7WJWaxWThxvG" for="ipyplot-html-viewer-toggle-TDAV5EW4jM7WJWaxWThxvG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TDAV5EW4jM7WJWaxWThxvG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-joghTEkoNpxtJE8cSdqWLP" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-joghTEkoNpxtJE8cSdqWLP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-DqsfFMSExWaHuSf4bEnvor" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-DqsfFMSExWaHuSf4bEnvor">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-VpufKT4YUuwwoa38afG2ei" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-VpufKT4YUuwwoa38afG2ei">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-h7BKN7VhwqoMmJwneKtyqN" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-h7BKN7VhwqoMmJwneKtyqN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-aKiBAghGGQXenLqonZZcbX" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-aKiBAghGGQXenLqonZZcbX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-UVn6wBvrXij8oczmv8Xib7" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-UVn6wBvrXij8oczmv8Xib7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-mHEvEUNW4ffkN6GF4izcK6" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-mHEvEUNW4ffkN6GF4izcK6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-2ystew7mACpNE7qvHcLn2
#         <style>
#         #ipyplot-imgs-container-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-joghTEkoNpxtJE8cSdqWLP" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-joghTEkoNpxtJE8cSdqWLP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-DqsfFMSExWaHuSf4bEnvor" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-DqsfFMSExWaHuSf4bEnvor">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-VpufKT4YUuwwoa38afG2ei" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-VpufKT4YUuwwoa38afG2ei">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-h7BKN7VhwqoMmJwneKtyqN" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-h7BKN7VhwqoMmJwneKtyqN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-aKiBAghGGQXenLqonZZcbX" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-aKiBAghGGQXenLqonZZcbX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-UVn6wBvrXij8oczmv8Xib7" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-UVn6wBvrXij8oczmv8Xib7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-mHEvEUNW4ffkN6GF4izcK6" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-mHEvEUNW4ffkN6GF4izcK6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#         <div id="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-2ystew7mACpNE7qvHcLn2v" class="ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZDmjYkQ5CDWe3goQ86Rtf9-2ystew7mACpNE7qvHcLn2v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
